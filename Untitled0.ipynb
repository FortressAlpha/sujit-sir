# %% [markdown]
# <a href="https://colab.research.google.com/github/FortressAlpha/sujit-sir/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (1,2,3,4)
print(sum(t))
# Out:
# 10

# %%
t = (1,2,3,2,4,2,5)
e = 3
print(t.count(e))
# Out:
# 1

# %%
t = (10,20,30,40)
print(t.index(30))
# Out:
# 2

# %%
t = (1,2,2,3,4,4)
l = list(t)
r = list(set(l))
print(r)
# Out:
# [1, 2, 3, 4]

# %%
t = (1,2,3,4)
p = 1
for i in t:
  p*=i
  print(p)
# Out:
# 1
# 2
# 6
# 24

# %%
d = {'A':50,'B':20,'C':30}
s = dict(sorted(d.items(),key=lambda x:x[1]))
print(s)
# Out:
# {'B': 20, 'C': 30, 'A': 50}

# %%
l = [1,2,3,4,5,6]
r = {'Even':[],'Odd':[]}
for i in l:
  if i%2==0:
    r["Even"].append(i)

  else:
    r["Odd"].append(i)
print(r)
# Out:
# {'Even': [2, 4, 6], 'Odd': [1, 3, 5]}

# %%
s = "Hello world"
v = "aeiou"
c = {}

for ch in s:
  if ch in v:
    c[ch] = c.get(ch,0)+1
print(c)
# Out:
# {'e': 1, 'o': 2}
